# %%
comps[["competition_name", "season_name", "competition_id", "season_id"]]
# Out:
#           competition_name season_name  competition_id  season_id
# 0            1. Bundesliga   2023/2024               9        281
# 1            1. Bundesliga   2015/2016               9         27
# 2   African Cup of Nations        2023            1267        107
# 3         Champions League   2018/2019              16          4
# 4         Champions League   2017/2018              16          1
# ..                     ...         ...             ...        ...
# 75      UEFA Europa League   1988/1989              35         75
# 76       UEFA Women's Euro        2025              53        315
# 77       UEFA Women's Euro        2022              53        106
# 78       Women's World Cup        2023              72        107
# 79       Women's World Cup        2019              72         30
#
# [80 rows x 4 columns]

# %%
matches = sb.matches(competition_id=43, season_id=106)
matches.shape
# Out:
# /home/matias-peralta/personalP/football-dw/.venv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# (64, 55)

# %%
events = sb.events(match_id=matches["match_id"].iloc[0])
events["type"].value_counts()
# Out:
# type
# Pass                 955
# Ball Receipt*        868
# Carry                782
# Pressure             289
# Ball Recovery         93
# Duel                  63
# Clearance             41
# Dribble               39
# Miscontrol            32
# Foul Committed        31
# Foul Won              31
# Block                 27
# Dispossessed          23
# Dribbled Past         23
# Interception          23
# Goal Keeper           16
# Shot                  12
# Substitution          10
# Tactical Shift         5
# Half Start             4
# Half End               4
# Injury Stoppage        4
# Referee Ball-Drop      4
# Starting XI            2
# 50/50                  2
# Error                  1
# Shield                 1
# Own Goal For           1
# Own Goal Against       1
# Offside                1
# Name: count, dtype: int64

# %%
comps[comps["competition_name"].str.contains("World Cup")]
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 29            1470        274  International  FIFA U20 World Cup
# 30              43        106  International      FIFA World Cup
# 31              43          3  International      FIFA World Cup
# 32              43         55  International      FIFA World Cup
# 33              43         54  International      FIFA World Cup
# 34              43         51  International      FIFA World Cup
# 35              43        272  International      FIFA World Cup
# 36              43        270  International      FIFA World Cup
# 37              43        269  International      FIFA World Cup
# 78              72        107  International   Women's World Cup
# 79              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 29               male               True                       True
# ...

# %%
import duckdb

con = duckdb.connect("data/football.duckdb")

# Total event count
con.execute("SELECT count(*) FROM raw.events").df()
# Out:
#    count_star()
# 0        234637

# %%
con.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'raw'").df()
# Out:
#      table_name
# 0  competitions
# 1        events
# 2       matches
